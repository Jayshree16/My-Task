# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayshree16/My-Task/blob/main/1_LinearRe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x = np.array([[1],[2],[3],[4],[5]])
y = np.array([2,4,3,5,3])

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)

# %%
print(y_pred)
# Out:
# [2.8 3.1 3.4 3.7 4. ]

# %%
print(f"coefficient: {model.coef_}")
print(f"intercept: {model.intercept_}")
# Out:
# coefficient: [0.3]
# intercept: 2.5

# %%
plt.scatter(x,y,color = "blue" , label = "Actual")
plt.plot(x,y_pred,color = "red" , label = "Predicted")
plt.xlabel
plt.title("Linear Regression")
plt.legend()
plt.show()
